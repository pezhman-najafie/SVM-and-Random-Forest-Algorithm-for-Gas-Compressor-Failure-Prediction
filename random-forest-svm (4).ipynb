# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the dataset
df = pd.read_csv('/kaggle/input/dataset-sgt1/sgt400_cleaned_balanced_dataset12.csv')

# Select the first two columns and the label column
x_col = df.columns[0]  # First column name
y_col = df.columns[1]  # Second column name
label_col = df.columns[-1]  # Last column as the label

# Count the number of instances for each class
class_counts = df[label_col].value_counts()
print(f"Class 0 count: {class_counts.get(0, 0)}")
print(f"Class 1 count: {class_counts.get(1, 0)}")

# Plot the scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x=x_col, y=y_col, hue=label_col, alpha=0.7, palette=['red', 'blue'])
plt.xlabel(x_col)
plt.ylabel(y_col)
plt.title("Scatter Plot of Two Features Based on Labels")
plt.legend(title="Label")
plt.show()
# Out:
# Class 0 count: 200000
# Class 1 count: 200000

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Display descriptive statistics for each feature
print("Statistics for each feature:\n", df.describe())

# Plot histograms for all features
df.hist(figsize=(12, 8), bins=30, edgecolor='black')
plt.suptitle("Histogram of Features", fontsize=16)
plt.show()


# Plot histograms for each feature separately
for column in df.columns:
    plt.figure(figsize=(8, 6))
    df[column].hist(bins=30, edgecolor='black')
    plt.title(f"Histogram of {column}")
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# Plot box plots for all features
plt.figure(figsize=(12, 6))
sns.boxplot(data=df)
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.title("Box Plot of Features")
plt.show()

# Scatter plot for the first two features based on labels
x_col = df.columns[2]  # First feature column
y_col = df.columns[3]  # Second feature column
label_col = df.columns[-1]  # Last column as the label

plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x=x_col, y=y_col, hue=label_col, alpha=0.7, palette=['red', 'blue'])
plt.xlabel(x_col)
plt.ylabel(y_col)
plt.title("Scatter Plot of Two Features Based on Labels")
plt.legend(title="Label")
plt.show()
# Out:
# Statistics for each feature:
#         Ambient Temperature  Ambient Pressure       Humidity    Load Demand  \
# count        400000.000000     400000.000000  400000.000000  400000.000000
# mean             25.014835        101.477114      50.011157      74.947684
# std              15.611323         10.728066      23.549880      27.615314
# min              -5.000000         78.000000      10.000000      30.000000
# 25%              13.059406         96.618831      27.721172      47.525450
# 50%              25.022659        101.489177      49.988845      74.986250
# 75%              36.957695        106.355340      72.341540     102.407699
# max              55.000000        125.000000      90.000000     120.000000
#
#        Turbine Speed  Exhaust Gas Temperature  Compressor Discharge Pressure  \
# count  400000.000000            400000.000000                  400000.000000
# mean    11001.931161               580.034026                     348.896059
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Display descriptive statistics for each feature
print("Statistics for each feature:\n", df.describe())

# Plot histograms for all features
df.hist(figsize=(12, 8), bins=30, edgecolor='black')
plt.suptitle("Histogram of Features", fontsize=16)
plt.show()

# Plot box plots for all features
plt.figure(figsize=(12, 6))
sns.boxplot(data=df)
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.title("Box Plot of Features")
plt.show()

# Scatter plot for the first two features based on labels
x_col = df.columns[2]  # First feature column
y_col = df.columns[3]  # Second feature column
label_col = df.columns[-1]  # Last column as the label

plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x=x_col, y=y_col, hue=label_col, alpha=0.7, palette=['red', 'blue'])
plt.xlabel(x_col)
plt.ylabel(y_col)
plt.title("Scatter Plot of Two Features Based on Labels")
plt.legend(title="Label")
plt.show()
# Out:
# Statistics for each feature:
#         Ambient Temperature  Ambient Pressure       Humidity    Load Demand  \
# count        400000.000000     400000.000000  400000.000000  400000.000000
# mean             25.014835        101.477114      50.011157      74.947684
# std              15.611323         10.728066      23.549880      27.615314
# min              -5.000000         78.000000      10.000000      30.000000
# 25%              13.059406         96.618831      27.721172      47.525450
# 50%              25.022659        101.489177      49.988845      74.986250
# 75%              36.957695        106.355340      72.341540     102.407699
# max              55.000000        125.000000      90.000000     120.000000
#
#        Turbine Speed  Exhaust Gas Temperature  Compressor Discharge Pressure  \
# count  400000.000000            400000.000000                  400000.000000
# mean    11001.931161               580.034026                     348.896059
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Calculate the correlation matrix
corr_matrix = df.corr()

# Display the correlation matrix
print("Correlation Matrix:\n", corr_matrix)

# Plot the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("Correlation Matrix Heatmap")
plt.show()
# Out:
# Correlation Matrix:
#                                 Ambient Temperature  Ambient Pressure  \
# Ambient Temperature                       1.000000         -0.002398
# Ambient Pressure                         -0.002398          1.000000
# Humidity                                 -0.000032          0.002261
# Load Demand                               0.001496         -0.000811
# Turbine Speed                            -0.000607         -0.002310
# Exhaust Gas Temperature                   0.000911          0.000198
# Compressor Discharge Pressure             0.003236         -0.007262
# Vibration Data                           -0.002882         -0.005070
# Temperature Data                          0.091806         -0.002640
# Pressure Data                             0.000630         -0.008715
# Oil Data                                  0.010710          0.003232
# Fuel Type_Contaminated Diesel             0.000141         -0.003797
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Read the dataset
df = pd.read_csv('/kaggle/input/dataset-sgt1/sgt400_cleaned_balanced_dataset12.csv')

# Select features (excluding the last column, which is the label)
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# Normalize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the dataset (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42, stratify=y)

# Define models with fixed parameters
rf_model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=42)
svm_model = SVC(C=1.0, kernel='rbf', gamma='scale', random_state=42)

# Train models
rf_model.fit(X_train, y_train)
svm_model.fit(X_train, y_train)

# Predictions
y_pred_rf = rf_model.predict(X_test)
y_pred_svm = svm_model.predict(X_test)

# Evaluation
accuracy_rf_test = accuracy_score(y_test, y_pred_rf)
accuracy_svm_test = accuracy_score(y_test, y_pred_svm)

# Classification reports
report_rf = classification_report(y_test, y_pred_rf, output_dict=True)
report_svm = classification_report(y_test, y_pred_svm, output_dict=True)

# Extract Precision, Recall, and F1-Score
metrics = ['precision', 'recall', 'f1-score']
rf_scores = [report_rf['weighted avg'][metric] for metric in metrics]
svm_scores = [report_svm['weighted avg'][metric] for metric in metrics]

print(f"Random Forest - Test Accuracy: {accuracy_rf_test:.4f}")
print(f"SVM - Test Accuracy: {accuracy_svm_test:.4f}")

# Print scores
print("Random Forest Metrics:")
print(f"Precision: {rf_scores[0]:.4f}, Recall: {rf_scores[1]:.4f}, F1-Score: {rf_scores[2]:.4f}\n")
print("SVM Metrics:")
print(f"Precision: {svm_scores[0]:.4f}, Recall: {svm_scores[1]:.4f}, F1-Score: {svm_scores[2]:.4f}\n")

# Bar plot for Precision, Recall, and F1-Score
x_labels = ['Precision', 'Recall', 'F1-Score']
x = np.arange(len(metrics))

plt.figure(figsize=(8, 6))
plt.bar(x - 0.2, rf_scores, width=0.4, label='Random Forest', color='blue', alpha=0.7)
plt.bar(x + 0.2, svm_scores, width=0.4, label='SVM', color='red', alpha=0.7)
plt.xticks(ticks=x, labels=x_labels)
plt.ylabel("Score")
plt.title("Comparison of Precision, Recall, and F1-Score")
plt.legend()
plt.show()

# Comparison of accuracy
plt.figure(figsize=(6, 4))
plt.bar(['Random Forest', 'SVM'], [accuracy_rf_test, accuracy_svm_test], color=['blue', 'red'], alpha=0.7)
plt.ylabel("Accuracy")
plt.title("Comparison of Model Accuracy")
plt.show()

# Confusion Matrices
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
sns.heatmap(confusion_matrix(y_test, y_pred_rf), annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title("Random Forest - Confusion Matrix")
axes[0].set_xlabel("Predicted")
axes[0].set_ylabel("Actual")

sns.heatmap(confusion_matrix(y_test, y_pred_svm), annot=True, fmt='d', cmap='Oranges', ax=axes[1])
axes[1].set_title("SVM - Confusion Matrix")
axes[1].set_xlabel("Predicted")
axes[1].set_ylabel("Actual")

plt.show()
# Out:
# Random Forest - Test Accuracy: 1.0000
# SVM - Test Accuracy: 1.0000
# Random Forest Metrics:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
#
# SVM Metrics:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import (accuracy_score, classification_report, confusion_matrix, 
                             roc_curve, auc, precision_recall_fscore_support)

# Read the dataset
df = pd.read_csv('/kaggle/input/dataset-sgt1/sgt400_cleaned_balanced_dataset12.csv')

# Select features (excluding the last column, which is the label)
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# Normalize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the dataset (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42, stratify=y)

# Initialize models
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
svm_model = SVC(kernel='rbf', probability=True, random_state=42)

# Train models
rf_model.fit(X_train, y_train)
svm_model.fit(X_train, y_train)

# Predictions
y_pred_rf = rf_model.predict(X_test)
y_pred_svm = svm_model.predict(X_test)

# Evaluation metrics
metrics = {}
for name, y_pred, model in zip(["Random Forest", "SVM"], [y_pred_rf, y_pred_svm], [rf_model, svm_model]):
    acc = accuracy_score(y_test, y_pred)
    prec, rec, f1, _ = precision_recall_fscore_support(y_test, y_pred, average='weighted')
    metrics[name] = [acc, prec, rec, f1]
    print(f"\n{name} Classification Report:\n", classification_report(y_test, y_pred))

# Confusion Matrix
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
for ax, name, y_pred in zip(axes, ["Random Forest", "SVM"], [y_pred_rf, y_pred_svm]):
    cm = confusion_matrix(y_test, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax)
    ax.set_title(f'{name} Confusion Matrix')
    ax.set_xlabel('Predicted')
    ax.set_ylabel('Actual')
plt.tight_layout()
plt.show()

# Compare metrics
metrics_df = pd.DataFrame(metrics, index=["Accuracy", "Precision", "Recall", "F1 Score"])
metrics_df.plot(kind='bar', figsize=(10, 6), colormap='viridis', edgecolor='black')
plt.title("Comparison of Evaluation Metrics")
plt.ylabel("Score")
plt.xticks(rotation=0)
plt.legend(title="Algorithm")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# ROC Curve
plt.figure(figsize=(8, 6))
for name, model in zip(["Random Forest", "SVM"], [rf_model, svm_model]):
    y_prob = model.predict_proba(X_test)[:, 1]
    fpr, tpr, _ = roc_curve(y_test, y_prob)
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'{name} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()
# Out:
# Random Forest Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     60000
#            1       1.00      1.00      1.00     60000
#
#     accuracy                           1.00    120000
#    macro avg       1.00      1.00      1.00    120000
# weighted avg       1.00      1.00      1.00    120000
#
#
# SVM Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     60000
#            1       1.00      1.00      1.00     60000
#
#     accuracy                           1.00    120000
#    macro avg       1.00      1.00      1.00    120000
# weighted avg       1.00      1.00      1.00    120000

# %%
feature_importances = rf_model.feature_importances_
features = X.columns

plt.figure(figsize=(8, 6))
sns.barplot(x=feature_importances, y=features, palette='viridis')
plt.xlabel("Feature Importance Score")
plt.ylabel("Features")
plt.title("Feature Importance in Random Forest")
plt.show()

# %%
from sklearn.model_selection import learning_curve

train_sizes, train_scores, test_scores = learning_curve(rf_model, X_scaled, y, cv=5, scoring='accuracy')

train_mean = np.mean(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)

plt.figure(figsize=(8, 6))
plt.plot(train_sizes, train_mean, label="Training Score", marker='o')
plt.plot(train_sizes, test_mean, label="Validation Score", marker='s')
plt.xlabel("Training Samples")
plt.ylabel("Accuracy")
plt.title("Learning Curve")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(y_pred_rf, color="blue", label="Random Forest", kde=True, bins=20, alpha=0.6)
sns.histplot(y_pred_svm, color="red", label="SVM", kde=True, bins=20, alpha=0.6)
plt.xlabel("Predicted Class")
plt.ylabel("Count")
plt.title("Prediction Distribution")
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
from sklearn.inspection import permutation_importance


perm_importance = permutation_importance(svm_model, X_test, y_test, scoring='accuracy', n_repeats=10, random_state=42)


plt.figure(figsize=(8, 6))
sns.barplot(x=perm_importance.importances_mean, y=X.columns, palette='magma')
plt.xlabel("Permutation Importance Score")
plt.ylabel("Features")
plt.title("Feature Importance in SVM (Permutation Importance)")
plt.show()

# %%
import pandas as pd
import numpy as np
import torch
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import torch.nn as nn
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv('/kaggle/input/dataset-sgt1/sgt400_cleaned_balanced_dataset12.csv')

# Select features and target
target_col = 'Ambient Temperature'
feature_cols = [col for col in df.columns if col != target_col]

# Standardize features
scaler_X = StandardScaler()
scaler_y = StandardScaler()

X_scaled = scaler_X.fit_transform(df[feature_cols])
y_scaled = scaler_y.fit_transform(df[[target_col]])

# Convert to PyTorch tensors
X_tensor = torch.tensor(X_scaled, dtype=torch.float32)
y_tensor = torch.tensor(y_scaled, dtype=torch.float32)

# Create sequences
def create_sequences(X, y, seq_length=20):
    sequences, targets = [], []
    for i in range(len(X) - seq_length):
        sequences.append(X[i:i+seq_length])
        targets.append(y[i+seq_length])
    return torch.stack(sequences), torch.stack(targets)

seq_length = 20
X_sequences, y_sequences = create_sequences(X_tensor, y_tensor, seq_length)

# Split into train and test sets
train_size = int(0.8 * len(X_sequences))
X_train, X_test = X_sequences[:train_size], X_sequences[train_size:]
y_train, y_test = y_sequences[:train_size], y_sequences[train_size:]

# Create DataLoader
batch_size = 32
train_loader = DataLoader(TensorDataset(X_train, y_train), batch_size=batch_size, shuffle=True)
test_loader = DataLoader(TensorDataset(X_test, y_test), batch_size=batch_size, shuffle=False)

# Define LSTM Model
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size=64, output_size=1):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
    
    def forward(self, x):
        lstm_out, _ = self.lstm(x)
        output = self.fc(lstm_out[:, -1, :])  # Take the last time step output
        return output

# Initialize model
input_size = len(feature_cols)
model = LSTMModel(input_size)

# Loss function & optimizer
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# Train model
def train_model(model, train_loader, test_loader, epochs=10):
    train_losses, test_losses = [], []

    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()
            output = model(X_batch)
            loss = criterion(output, y_batch)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        
        avg_train_loss = running_loss / len(train_loader)
        train_losses.append(avg_train_loss)

        # Evaluate on test set
        model.eval()
        test_loss = 0.0
        y_preds, y_trues = [], []
        with torch.no_grad():
            for X_batch, y_batch in test_loader:
                output = model(X_batch)
                loss = criterion(output, y_batch)
                test_loss += loss.item()
                y_preds.append(output.numpy())
                y_trues.append(y_batch.numpy())

        avg_test_loss = test_loss / len(test_loader)
        test_losses.append(avg_test_loss)

        print(f"Epoch [{epoch+1}/{epochs}], Train Loss: {avg_train_loss:.4f}, Test Loss: {avg_test_loss:.4f}")

    return train_losses, test_losses, np.concatenate(y_preds), np.concatenate(y_trues)

# Train the model
train_losses, test_losses, y_preds, y_trues = train_model(model, train_loader, test_loader, epochs=10)

# Convert predictions back to original scale
y_preds_original = scaler_y.inverse_transform(y_preds)
y_trues_original = scaler_y.inverse_transform(y_trues)

# Calculate error metrics
mae = mean_absolute_error(y_trues_original, y_preds_original)
rmse = np.sqrt(mean_squared_error(y_trues_original, y_preds_original))
r2 = r2_score(y_trues_original, y_preds_original)

print(f"MAE: {mae:.4f}, RMSE: {rmse:.4f}, R²: {r2:.4f}")

# Plot training and test loss
plt.figure(figsize=(10, 6))
plt.plot(train_losses, label='Train Loss')
plt.plot(test_losses, label='Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Test Loss Over Epochs')
plt.show()

# Plot true vs predicted values
plt.figure(figsize=(10, 6))
plt.plot(y_trues_original, label='True Values', color='blue')
plt.plot(y_preds_original, label='Predictions', color='red')
plt.xlabel('Time Steps')
plt.ylabel('Vibration Data')
plt.legend()
plt.title('True vs Predicted Vibration Data')
plt.show()
# Out:
# Epoch [1/10], Train Loss: 0.8657, Test Loss: 1.5399
# Epoch [2/10], Train Loss: 0.8653, Test Loss: 1.5402
# Epoch [3/10], Train Loss: 0.8652, Test Loss: 1.5401
# Epoch [4/10], Train Loss: 0.8650, Test Loss: 1.5404
# Epoch [5/10], Train Loss: 0.8645, Test Loss: 1.5419
# Epoch [6/10], Train Loss: 0.8637, Test Loss: 1.5424
# Epoch [7/10], Train Loss: 0.8617, Test Loss: 1.5468
# Epoch [8/10], Train Loss: 0.8571, Test Loss: 1.5540
# Epoch [9/10], Train Loss: 0.8505, Test Loss: 1.5657
# Epoch [10/10], Train Loss: 0.8412, Test Loss: 1.5786
# MAE: 17.5679, RMSE: 19.6147, R²: -0.0251

# %%
import pandas as pd
import numpy as np
import torch
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import StandardScaler
import torch.nn as nn
import matplotlib.pyplot as plt

# Function to load data from CSV without timestamp
def load_data_from_csv(csv_file):
    df = pd.read_csv(csv_file)  # Load the dataset from CSV
    return df

# Load the data
df = load_data_from_csv('/kaggle/input/dataset-sgt1/sgt400_cleaned_balanced_dataset12.csv')  # Specify your CSV file path here

# Selecting the 'Load Demand' feature for prediction
df_feature = df[['Load Demand']]  # Replace with the actual column name for 'Load Demand'

# %%
from sklearn.model_selection import train_test_split

# استانداردسازی داده‌ها
scaler = StandardScaler()
scaled_feature = scaler.fit_transform(df_feature)

# تقسیم داده‌ها به داده‌های آموزش و تست
train_size = int(len(scaled_feature) * 0.7)
train_data, test_data = scaled_feature[:train_size], scaled_feature[train_size:]

# تبدیل داده‌ها به توالی‌های زمانی برای LSTM
def create_sequences(data, seq_length):
    sequences = []
    labels = []
    for i in range(len(data) - seq_length):
        sequences.append(data[i:i + seq_length])
        labels.append(data[i + seq_length])
    return np.array(sequences), np.array(labels)

seq_length = 10  # طول توالی‌های زمانی
X_train, y_train = create_sequences(train_data, seq_length)
X_test, y_test = create_sequences(test_data, seq_length)

# تبدیل داده‌ها به Tensor
X_train_tensor = torch.Tensor(X_train)
y_train_tensor = torch.Tensor(y_train)
X_test_tensor = torch.Tensor(X_test)
y_test_tensor = torch.Tensor(y_test)

# بارگذاری داده‌ها
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_layer_size, output_size):
        super(LSTMModel, self).__init__()
        self.hidden_layer_size = hidden_layer_size
        self.lstm = nn.LSTM(input_size, hidden_layer_size, batch_first=True)
        self.linear = nn.Linear(hidden_layer_size, output_size)

    def forward(self, input_seq):
        lstm_out, _ = self.lstm(input_seq)
        predictions = self.linear(lstm_out[:, -1])
        return predictions

# پارامترهای مدل
input_size = 1  # تعداد ویژگی‌ها
hidden_layer_size = 64
output_size = 1

# ایجاد مدل
model = LSTMModel(input_size, hidden_layer_size, output_size)

# %%
# معیارهای ارزیابی
loss_function = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# آموزش مدل
epochs = 20
for epoch in range(epochs):
    model.train()
    epoch_loss = 0
    for batch in train_loader:
        X_batch, y_batch = batch
        optimizer.zero_grad()
        y_pred = model(X_batch)
        loss = loss_function(y_pred, y_batch)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
    
    print(f'Epoch {epoch+1}/{epochs}, Loss: {epoch_loss/len(train_loader)}')
# Out:
# Epoch 1/20, Loss: 0.7764437512738364
# Epoch 3/20, Loss: 0.7762232227461678
# Epoch 4/20, Loss: 0.7761724895341056
# Epoch 5/20, Loss: 0.7761759566307068
# Epoch 6/20, Loss: 0.7761793740476881
# Epoch 7/20, Loss: 0.7761884739535195
# Epoch 8/20, Loss: 0.7761872649465289
# Epoch 9/20, Loss: 0.776171270935876
# Epoch 10/20, Loss: 0.7761724254744393
# Epoch 11/20, Loss: 0.7761644089017595
# Epoch 12/20, Loss: 0.7761322568144117
# Epoch 13/20, Loss: 0.7761450165884836
# Epoch 14/20, Loss: 0.776162785591398
# Epoch 15/20, Loss: 0.7761325148173741
# Epoch 16/20, Loss: 0.776135109104429
# Epoch 17/20, Loss: 0.7761343972546714
# Epoch 18/20, Loss: 0.776141189111982
# Epoch 19/20, Loss: 0.7761114728110177
# Epoch 20/20, Loss: 0.7761264578274318

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# پیش‌بینی روی داده‌های تست
model.eval()
y_pred_list = []
y_test_list = []

with torch.no_grad():
    for batch in test_loader:
        X_batch, y_batch = batch
        y_pred = model(X_batch)
        y_pred_list.append(y_pred.numpy())
        y_test_list.append(y_batch.numpy())

# تبدیل لیست‌ها به آرایه‌های numpy
y_pred = np.concatenate(y_pred_list, axis=0)
y_test = np.concatenate(y_test_list, axis=0)

# معیارهای ارزیابی
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'RMSE: {rmse}')
print(f'MAE: {mae}')
print(f'R^2: {r2}')
# Out:
# RMSE: 1.2339212894439697
# MAE: 1.1816601753234863
# R^2: -8.271832664918932e-05

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['Load Demand'], marker='o', linestyle='-', color='b', alpha=0.7)
plt.xlabel('Index')
plt.ylabel('Load Demand')
plt.title('Load Demand vs. Index')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.scatter(df.index, df['Load Demand'], color='b', alpha=0.3, s=1)  # alpha برای شفافیت و s برای کاهش اندازه نقاط
plt.xlabel('Index')
plt.ylabel('Load Demand')
plt.title('Scatter Plot of Load Demand vs Index')
plt.grid(True)
plt.show()

# %%
window_size = 1000
df['Moving_Avg'] = df['Load Demand'].rolling(window=window_size).mean()

plt.figure(figsize=(12, 6))
plt.plot(df.index, df['Moving_Avg'], color='r', linestyle='-', label=f'Moving Average ({window_size} points)')
plt.xlabel('Index')
plt.ylabel('Load Demand')
plt.title('Load Demand Moving Average')
plt.legend()
plt.grid(True)
plt.show()
